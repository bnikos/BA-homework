# %% [markdown]
# Όπως είδαμε στο μάθημα (στο notebook: https://github.com/datajour-gr/DataJournalism/blob/main/Bachelor%20Lessons%202023/Lesson%206/Classwork6_Scraping_BBC.ipynb), ο κώδικας για να φέρουμε τον τίτλο, το url και την περίληψη όλων των άρθρων από μια σελίδα του bbc, είναι ο εξής:

# %%
# εισάγουμε τις βιβλιοθήκες
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# κατεβάζουμε τη σελίδα που θέλουμε
response = requests.get('http://www.bbc.co.uk/news')
doc = BeautifulSoup(response.text, 'html.parser')

# %%
# Ξεκινάμε με μια άδεια λίστα
stories_list = []
stories = doc.find_all('div', { 'class': 'gs-c-promo' })
for story in stories:
    # Φτιάχνουμε ένα λεξικό χωρίς τίποτα
    story_dict = {}
    headline = story.find('h3')
    if headline:
        story_dict['headline'] = headline.text
    link = story.find('a')
    if link:
        story_dict['url'] = link['href']
    summary = story.find('p')
    if summary:
        story_dict['summary'] = summary.text
    # Προσθέτουμε το λεξικό στη λίστα 
    stories_list.append(story_dict)
    
# Δημιουργούμε dataframe από τη λίστα με τα dictionaries
df = pd.DataFrame(stories_list)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Μετατρέπουμε το dataframe σε CSV και το αποθηκεύουμε στο drive.
# Xρησιμοποιούμε το index=False, για να μην αποθηκευτεί ο αύξοντας αριθμός των rows.
df = pd.DataFrame(stories_list)
df.to_csv("/content/drive/MyDrive/bbc.csv", index=False)

# %%
df
# Out:
#                                              headline  \
# 0   Harry and Meghan in 'near catastrophic car chase'
# 1   Harry's statement blames 'highly aggressive pa...
# 2   World likely to warm beyond key 1.5C limit by ...
# 3         North Carolina bans abortion after 12 weeks
# 4       Court orders Elizabeth Holmes to go to prison
# 5    Musk: I will say what I want even if it costs me
# 6   New negotiators raise hopes of US debt limit deal
# 7   Break-in at Biden aide's home while agents out...
# 8   Watch: Man grabs highly venomous snake on live...
# 9   Sarkozy to wear tag after losing corruption ap...
# 10       Woman, 97, among New Mexico shooting victims
# 11  Sarkozy to wear tag after losing corruption ap...
# 12       Woman, 97, among New Mexico shooting victims
# 13  UK car giant warns Brexit may force factory cl...
# 14  Watch: Child rescued from whirlwind in basebal...
# 15         US convoy ambushed in Nigeria, four killed
# ...

# %% [markdown]
# ## **Extra tips**

# %% [markdown]
# ### **Διόρθωση των ελλειπών urls**

# %% [markdown]
# Όπως βλέπουμε στο df, κάποια urls δεν είναι ολόκληρα, ενώ κάποια άλλα είναι. Παρατηρούμε ότι το κομμάτι που λείπει είναι το main url, δηλαδή το ```"https://www.bbc.com"```

# %% [markdown]
# Μπορούμε να διορθώσουμε τα ελλειπή urls με τον παρακάτω κώδικα:

# %%
df['url_new'] = df.apply(lambda x: x['url'] if x['url'].startswith("http") else "https://www.bbc.com" + x['url'], axis=1)

# %% [markdown]
# Ο παραπάνω κώδικας δημιουργεί μια νέα στήλη ('url_new') και σε κάθε row βάζει την τιμή του κελιού από τη στήλη 'url' αν η τιμή αρχίζει με 'http', αλλιώς προσθέτει στην αρχή της τιμής του κελιού 'url' το "http://www.bbc.com".

# %%
df
# Out:
#                                              headline  \
# 0   Harry and Meghan in 'near catastrophic car chase'
# 1   Harry's statement blames 'highly aggressive pa...
# 2   World likely to warm beyond key 1.5C limit by ...
# 3         North Carolina bans abortion after 12 weeks
# 4       Court orders Elizabeth Holmes to go to prison
# 5    Musk: I will say what I want even if it costs me
# 6   New negotiators raise hopes of US debt limit deal
# 7   Break-in at Biden aide's home while agents out...
# 8   Watch: Man grabs highly venomous snake on live...
# 9   Sarkozy to wear tag after losing corruption ap...
# 10       Woman, 97, among New Mexico shooting victims
# 11  Sarkozy to wear tag after losing corruption ap...
# 12       Woman, 97, among New Mexico shooting victims
# 13  UK car giant warns Brexit may force factory cl...
# 14  Watch: Child rescued from whirlwind in basebal...
# 15         US convoy ambushed in Nigeria, four killed
# ...

# %% [markdown]
# # **Άσκηση**

# %% [markdown]
# Κάνετε όποια/όποιες από τις παρακάτω ασκήσεις θέλετε:
#
# **1. Βαθμός δυσκολίας: πολύ εύκολο**
#
# Προσαρμόστε κατάλληλα τον κώδικα του notebook https://github.com/datajour-gr/DataJournalism/blob/main/Bachelor%20Lessons%202023/Lesson%206/Scraping%20with%20newspaper3k%20module.ipynb (με το module newspaper3k) για να μαζέψετε δεδομένα από τα άρθρα της κατηγορίας latest του news247 (https://www.news247.gr/latest/) και της efsyn.
#
# **2. Βαθμός δυσκολίας: εύκολο**
#
# Το ίδιο με παραπάνω (1) αλλά μαζέψτε δεδομένα από 3 σελίδες της κατηγορίας latest.
#
# Hint: χρησιμοποιήστε το /?page=
#
# **3. Βαθμός δυσκολίας: μέτριο**
#
# Προσαρμόστε κατάλληλα τον κώδικα που έχουμε χρησιμοποιήσει με το requests και το BeautifulSoup για να μαζέψετε δεδομένα άρθρων από την κατηγορία των τελευταίων ειδήσεων του news247 (https://www.news247.gr/latest/)
#
# Στη συνέχεια φτιάξτε μια for loop για να μαζέψετε πληροφορίες άρθρων από περισσότερες από μία σελίδες της ίδιας κατηγορίας (χρησιμοποιήστε το /?page=)
#
# **4a. Βαθμός δυσκολίας: προχωρημένο**
#
# Με τη χρήση του requests και του BeautifulSoup:
# 1. Μαζέψτε (μόνο) τα urls των άρθρων της Κυριακής 14/5/2023 από την κατηγορία των τελευταίων ειδήσεων του news247 (https://www.news247.gr/latest/?page=) και αποθηκεύστε τα σε μία λίστα.
# 2. Μαζέψτε για κάθε άρθρο στη λίστα τον τίτλο, το url του, την ημερομηνία, τον συντάκτη, την κατηγορία (section) και το κείμενο του άρθρου.
#
# **4b. Βαθμός δυσκολίας: προχωρημένο**
#
# Εναλλακτικά, μπορείτε να μαζέψετε τις πληροφορίες από reviews των χρηστών του trip advisor (π.χ. https://www.tripadvisor.com/AttractionProductReview-g189400-d11476899-Skip_the_Line_Acropolis_of_Athens_Afternoon_Walking_Tour-Athens_Attica.html).
#
# Μαζέψτε το rating (τα bubbles), τον τίτλο του review (π.χ. Highly recommend tour + museum), το πότε γράφτηκε το review και το text του review.
#
# **4c. Βαθμός δυσκολίας: προχωρημένο**
#
# Μπορείτε να μαζέψετε δεδομένα από σχόλια σε ένα video στο youtube (όνομα χρήστη, ημερομηνία, κείμενο).

# %%
#!pip install newspaper3k

# %%
import newspaper

# %%
news247_url = 'https://www.news247.gr/latest/'

# %%
news247 = newspaper.build(news247_url, memoize_articles=False)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.news247.gr/feed

# %%
news247_urlsL = news247.article_urls()

print(len(news247_urlsL))

news247_urlsL[:10]
# Out:
# 47
# ['https://www.news247.gr/ekloges/ekloges-2023-poly-psila-i-aristera-sta-apotelesmata-tis-danias.10054080.html',
#  'https://www.news247.gr/ekloges/ekloges-2023-stin-proedro-tis-dimokratias-o-nikos-androylakis-gia-ti-diereynitiki-entoli.10053932.html',
#  'https://www.oneman.gr/entertainment/to-the-idol-tou-hbo-prota-skandalise-tis-kannes-meta-apotheothike/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos1',
#  'https://www.oneman.gr/athlitika/carmelo-anthony-michael-jordan-xoris-ta-daxtilidia/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos2',
#  'https://www.oneman.gr/life/5-simadia-oti-o-manager-sou-einai-pragmatika-kalos/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos3',
#  'https://www.ladylike.gr/beauty/alexa-chung-o-freskos-tropos-pou-foraei-to-kokkino-kragion-3-gia-na-dialexeis/?utm_source=News247&utm_medium=footer&utm_campaign=24MediaWidget&utm_term=Pos1',
# ...

# %%
from newspaper import Article
import pandas as pd
import numpy as np

# %%
article1_1 = Article(news247_urlsL[0])
article1_1.download()
article1_1.parse()

# %%
print(article1_1.title)
print(article1_1.text)
print(article1_1.authors)
print(article1_1.top_image)
print(article1_1.images)
print(article1_1.movies)
print(article1_1.publish_date)
# Out:
# Εκλογές 2023: Ψηλά η Αριστερά στα αποτελέσματα της Δανίας
# Tα αποτελέσματα των εκλογών όσον αφορά τους Ελληνες που διαμένουν στη Δανία δεν είχαν καμία σχέση με αυτά που καταγράφηκαν στην ελληνική επικράτεια.
#
# Πρώτο κόμμα αναδείχθηκε ο ΣΥΡΙΖΑ με 28,66% ενώ δεύτερο ήταν το ΚΚΕ με 21,66%.
#
# ADVERTISING
#
# Στην τρίτη θέση βρέθηκε το ΜέΡΑ 25 με 19,75% ενώ η θριαμβεύτρια των εκλογών Νέα Δημοκρατία περιορίστηκε στο 14,65%.
#
# Πέμπτο, τελος, ήταν το ΠΑΣΟΚ με 5,73%.
#
# Ψήφισαν συνολικά 473 άτομα.
#
# Ακολουθήστε το News 24/7 στο Google News και μάθετε πρώτοι όλες τις ειδήσεις
# []
# https://www.news247.gr/img/2141/10047340/899000/fb1200/1200/kalpi.jpg
# ...

# %%
news247_articlesL = []
for url in news247_urlsL[:47]:
  news247_articleD = {}
  news247_article = Article(url)
  news247_article.download()
  news247_article.parse()
  news247_articleD['url'] = url
  if news247_article.publish_date is not None:
    news247_articleD['date'] = news247_article.publish_date
  else:
    news247_articleD['date'] = np.nan
  if news247_article.title is not None:
    news247_articleD['title'] = news247_article.title
  else:
    news247_articleD['title'] = np.nan
  if news247_article.top_image is not None:
    news247_articleD['top image'] = news247_article.top_image
  else:
    news247_articleD['top image'] = np.nan
  if news247_article.text is not None:
    news247_articleD['text'] = news247_article.text
  else:
    news247_articleD['text'] = np.nan
  if news247_article.authors is not None:
    news247_articleD['authors'] = news247_article.authors
  else:
    news247_articleD['authors'] = np.nan
  if news247_article.images is not None:
    news247_articleD['images'] = news247_article.images
  else:
    news247_articleD['images'] = np.nan
  if news247_article.movies is not None:
    news247_articleD['movies'] = news247_article.movies
  else:
    news247_articleD['movies'] = np.nan
  news247_articlesL.append(news247_articleD)

news247_df = pd.DataFrame(news247_articlesL)

# %%
news247_df
# Out:
#                                                   url  \
# 0   https://www.news247.gr/ekloges/ekloges-2023-po...
# 1   https://www.news247.gr/ekloges/ekloges-2023-st...
# 2   https://www.oneman.gr/entertainment/to-the-ido...
# 3   https://www.oneman.gr/athlitika/carmelo-anthon...
# 4   https://www.oneman.gr/life/5-simadia-oti-o-man...
# 5   https://www.ladylike.gr/beauty/alexa-chung-o-f...
# 6   https://www.ladylike.gr/women-today/to-ntokima...
# 7   https://www.ladylike.gr/celebrities/h-miley-cy...
# 8   https://www.ow.gr/living/trizonia-to-nisaki-to...
# 9   https://www.ow.gr/sintages/i-pio-nostimi-kai-x...
# 10  https://www.ow.gr/diatrofi/pos-tha-enisxisoume...
# 11  https://www.news247.gr/ekloges/ekloges-2023-st...
# 12  https://www.news247.gr/podcasts/ekloges-1989-1...
# 13  https://www.news247.gr/podcasts/1974-2019-eklo...
# 14  https://www.ow.gr/psychologia/to-paixnidi-pou-...
# 15  https://www.ow.gr/wellness/emminopafsi-den-sim...
# ...

# %%
efsyn_url = "https://www.efsyn.gr/news"

efsyn = newspaper.build(efsyn_url, memoize_articles=False)

efsyn_urlsL = efsyn.article_urls()

efsyn_articlesL = []
for url in efsyn_urlsL[:100]:
  efsyn_articleD = {}
  efsyn_article = Article(url)
  efsyn_article.download()
  efsyn_article.parse()
  efsyn_articleD['url'] = url
  if efsyn_article.publish_date is not None:
    efsyn_articleD['date'] = efsyn_article.publish_date
  else:
    efsyn_articleD['date'] = np.nan
  if efsyn_article.title is not None:
    efsyn_articleD['title'] = efsyn_article.title
  else:
    efsyn_articleD['title'] = np.nan
  if efsyn_article.top_image is not None:
    efsyn_articleD['top image'] = efsyn_article.top_image
  else:
    efsyn_articleD['top image'] = np.nan
  if efsyn_article.text is not None:
    efsyn_articleD['text'] = efsyn_article.text
  else:
    efsyn_articleD['text'] = np.nan
  if efsyn_article.authors is not None:
    efsyn_articleD['authors'] = efsyn_article.authors
  else:
    efsyn_articleD['authors'] = np.nan
  if efsyn_article.images is not None:
    efsyn_articleD['images'] = efsyn_article.images
  else:
    efsyn_articleD['images'] = np.nan
  if efsyn_article.movies is not None:
    efsyn_articleD['movies'] = efsyn_article.movies
  else:
    efsyn_articleD['movies'] = np.nan
  efsyn_articlesL.append(efsyn_articleD)

efsyn_df = pd.DataFrame(efsyn_articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feeds

# %%
efsyn_df
# Out:
#                                                   url  date  \
# 0   https://kiosk.efsyn.gr/efimerides-2023/4508/23...   NaN
# 1   https://kiosk.efsyn.gr/efimerides-2023/4507/22...   NaN
# 2   https://kiosk.efsyn.gr/efimerides-2023/4506/20...   NaN
# 3   https://kiosk.efsyn.gr/efimerides-2023/4505/19...   NaN
# 4   https://kiosk.efsyn.gr/efimerides-2023/4504/18...   NaN
# ..                                                ...   ...
# 95  https://www.efsyn.gr/nisides/390456_o-kazantza...   NaN
# 96  https://www.efsyn.gr/nisides/390454_tote-poy-o...   NaN
# 97  https://www.efsyn.gr/nisides/390450_mprosta-st...   NaN
# 98  https://www.efsyn.gr/ellada/astynomiko/390936_...   NaN
# 99  https://www.efsyn.gr/ellada/dikaiosyni/390935_...   NaN
#
#                                                 title  \
# 0                                                2023
# 1                                                2025
# 2                                                2023
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.youtube.com/watch?v=EJvbU1bx2GQ')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
comments = soup.find_all('div', {'class': 'style-scope ytd-comment-renderer'})

for comment in comments:
  print(comment.text)
  print(comment['yt-formatted-string'])

# %%
response = requests.get('https://www.efsyn.gr/news?page=1')
soup2 = BeautifulSoup(response.text, 'html.parser')

# %%
articles = soup2.find_all('div', {'class': 'full-link'})

for article in articles:
  print(article['href'])

# %%
efsyn_articlesL = []

for page in range(1, 3):
  efsyn_url = "https://www.efsyn.gr/news?page=" + str(page)
  efsyn = newspaper.build(efsyn_url, memoize_articles=False)

  efsyn_urlsL = efsyn.article_urls()

  efsyn_articlesL = []
  for url in efsyn_urlsL[:50]:
    efsyn_articleD = {}
    efsyn_article = Article(url)
    efsyn_article.download()
    efsyn_article.parse()
    efsyn_articleD['url'] = url
    if efsyn_article.publish_date is not None:
      efsyn_articleD['date'] = efsyn_article.publish_date
    else:
      efsyn_articleD['date'] = np.nan
    if efsyn_article.title is not None:
      efsyn_articleD['title'] = efsyn_article.title
    else:
      efsyn_articleD['title'] = np.nan
    if efsyn_article.top_image is not None:
      efsyn_articleD['top image'] = efsyn_article.top_image
    else:
      efsyn_articleD['top image'] = np.nan
    if efsyn_article.text is not None:
      efsyn_articleD['text'] = efsyn_article.text
    else:
      efsyn_articleD['text'] = np.nan
    if efsyn_article.authors is not None:
      efsyn_articleD['authors'] = efsyn_article.authors
    else:
      efsyn_articleD['authors'] = np.nan
    if efsyn_article.images is not None:
      efsyn_articleD['images'] = efsyn_article.images
    else:
      efsyn_articleD['images'] = np.nan
    if efsyn_article.movies is not None:
      efsyn_articleD['movies'] = efsyn_article.movies
    else:
      efsyn_articleD['movies'] = np.nan
    efsyn_articlesL.append(efsyn_articleD)

  efsyn_df = pd.DataFrame(efsyn_articlesL)
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feeds
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.efsyn.gr/feeds

# %%
efsyn_df
# Out:
#                                                   url  date  \
# 0   https://kiosk.efsyn.gr/efimerides-2023/4508/23...   NaN
# 1   https://kiosk.efsyn.gr/efimerides-2023/4507/22...   NaN
# 2   https://kiosk.efsyn.gr/efimerides-2023/4506/20...   NaN
# 3   https://kiosk.efsyn.gr/efimerides-2023/4505/19...   NaN
# 4   https://kiosk.efsyn.gr/efimerides-2023/4504/18...   NaN
# 5   https://kiosk.efsyn.gr/efimerides-2023/4503/17...   NaN
# 6   https://kiosk.efsyn.gr/efimerides-2023/4502/16...   NaN
# 7   https://kiosk.efsyn.gr/efimerides-2023/4501/15...   NaN
# 8   https://kiosk.efsyn.gr/entheta/4334/TO-APOTYPO...   NaN
# 9   https://kiosk.efsyn.gr/entheta/4333/PROTAGONIS...   NaN
# 10  https://kiosk.efsyn.gr/istorika-vivlia/4336/AN...   NaN
# 11  https://kiosk.efsyn.gr/istorika-vivlia/4337/MA...   NaN
# 12  https://kiosk.efsyn.gr/diafora-vivlia/4154/EGO...   NaN
# 13  https://kiosk.efsyn.gr/istorika-vivlia/4156/OI...   NaN
# 14                  https://www.efsyn.gr/tehnes/media   NaN
# ...
